# %%
import spacy
#!python -m spacy download en_core_web_sm

from spacy import displacy

nlp = spacy.load("en_core_web_sm")

texts = [
    "The government raised interest rates.",
    "The internet gives everyone a voice.",
    "The man saw the dog with the telescope."
]

docs = []
for text in texts:
    docs.append(nlp(text))


for doc in docs:
    for token in doc:
        print(token.text, token.dep_, token.head.text, token.pos, [child for child in token.children])
    
    print("\n")
# Out:
# The det government 90 []
# government nsubj raised 92 [The]
# raised ROOT raised 100 [government, rates, .]
# interest compound rates 92 []
# rates dobj raised 92 [interest]
# . punct raised 97 []
#
#
# The det internet 90 []
# internet nsubj gives 92 [The]
# gives ROOT gives 100 [internet, everyone, voice, .]
# everyone dative gives 95 []
# a det voice 90 []
# voice dobj gives 92 [a]
# . punct gives 97 []
#
#
# The det man 90 []
# man nsubj saw 92 [The]
# saw ROOT saw 100 [man, dog, .]
# the det dog 90 []
# dog dobj saw 92 [the, with]
# with prep dog 85 [telescope]
# the det telescope 90 []
# telescope pobj with 92 [the]
# . punct saw 97 []

# %%
for doc in docs:
    displacy.render(doc, style="dep", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="b4f841c810b74f38aa66943960ecf4bf-0" class="displacy" width="925" height="312.0" direction="ltr" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">government</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
# ...
